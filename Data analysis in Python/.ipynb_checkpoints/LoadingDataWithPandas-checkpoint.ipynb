# %%
import pandas as pd

# %%
# Loading dataframes - csv
csv_path = 'Datasets/SubclassDemand_CROPP.csv'
df = pd.read_csv(csv_path, sep = ";" )
df.head()
# Out:
#   Country Group     Department      Subclass Store Category  \
# 0        Non-UE  ladies' CROPP  t-shirts_s_s              A
# 1        Non-UE  ladies' CROPP  t-shirts_s_s              B
# 2        Non-UE  ladies' CROPP  t-shirts_s_s              C
# 3        Non-UE  ladies' CROPP  t-shirts_s_s              D
# 4        RUSSIA  ladies' CROPP  t-shirts_s_s              A
#
#    Total Stores Count  Avg Stcl Cnt  Store Count Demand Avg  \
# 0                  11           137           10      84,34
# 1                   5           136            4      23,79
# 2                   7           118            7      31,04
# 3                   1           143            1       2,92
# 4                  18           149           18     169,28
#
#   Demand Avg With Min/Max  Avg Stcl Cnt Max  Store Count.1 Demand Max  \
# 0                   84,34                20             10     232,73
# 1                   23,79                20              4      59,44
# ...

# %%
# Loading dataframes - Excel
xlsx_path = 'Datasets/SubclassDemand_CROPP.xlsx'
df = pd.read_excel(xlsx_path, sep = ";")
df.head()
# Out:
#   Country Group     Department      Subclass Store Category  \
# 0        Non-UE  ladies' CROPP  t-shirts_s_s              A
# 1        Non-UE  ladies' CROPP  t-shirts_s_s              B
# 2        Non-UE  ladies' CROPP  t-shirts_s_s              C
# 3        Non-UE  ladies' CROPP  t-shirts_s_s              D
# 4        RUSSIA  ladies' CROPP  t-shirts_s_s              A
#
#    Total Stores Count  Avg Stcl Cnt  Store Count  Demand Avg  \
# 0                  11           137           10   84.336166
# 1                   5           136            4   23.789995
# 2                   7           118            7   31.042260
# 3                   1           143            1    2.919945
# 4                  18           149           18  169.276232
#
#    Demand Avg With Min/Max  Avg Stcl Cnt Max  Store Count.1  Demand Max  \
# 0                84.336166                20             10  232.726233
# 1                23.789995                20              4   59.437176
# ...

# %%
# Dataframes
songs = {'Album': ['Thriller', 'Back in Back', 'The Dark Side', 'The Bodyguard', 'Bat Out of Hell'],
         'Released': [1982, 1980, 1973, 1992, 1977],
         'Length': ['00:42:19', '00:42:11', '00:42:49', '00:57:44', '00:46:33']}

songs_frame = pd.DataFrame(songs)
songs_frame.head()
# Out:
#              Album  Released    Length
# 0         Thriller      1982  00:42:19
# 1     Back in Back      1980  00:42:11
# 2    The Dark Side      1973  00:42:49
# 3    The Bodyguard      1992  00:57:44
# 4  Bat Out of Hell      1977  00:46:33

# %%
# Create new dataframe
x = df[['Subclass']]
x.head()
# Out:
#        Subclass
# 0  t-shirts_s_s
# 1  t-shirts_s_s
# 2  t-shirts_s_s
# 3  t-shirts_s_s
# 4  t-shirts_s_s

# %%
y = df[['Department', 'Subclass', 'Demand Avg']]
y.head()
# Out:
#       Department      Subclass  Demand Avg
# 0  ladies' CROPP  t-shirts_s_s   84.336166
# 1  ladies' CROPP  t-shirts_s_s   23.789995
# 2  ladies' CROPP  t-shirts_s_s   31.042260
# 3  ladies' CROPP  t-shirts_s_s    2.919945
# 4  ladies' CROPP  t-shirts_s_s  169.276232

# %%
# First row
df.iloc[0,]
# Out:
# Country Group                             Non-UE
# Department                         ladies' CROPP
# Subclass                            t-shirts_s_s
# Store Category                                 A
# Total Stores Count                            11
# Avg Stcl Cnt                                 137
# Store Count                                   10
# Demand Avg                               84.3362
# Demand Avg With Min/Max                  84.3362
# Avg Stcl Cnt Max                              20
# Store Count.1                                 10
# Demand Max                               232.726
# Demand Max With Min/Max                  232.726
# Avg Wsp Alokacyjny                       7.66692
# Max Wsp Alokacyjny                       21.1569
# Avg Wsp Alokacyjny With Min/Max          7.66692
# Max Wsp Alokacyjny With Min/Max          21.1569
# Name: 0, dtype: object

# %%
# Fourth row - fourth column 
df.iloc[ 3, 3]
# Out:
# 'D'

# %%
# Name location
df.loc[10, 'Demand Avg']
# Out:
# 528.521608

# %%
# Index location
df.iloc[10, 7]
# Out:
# 528.521608

# %%
df.iloc[0:4, 0:5]
# Out:
#   Country Group     Department      Subclass Store Category  \
# 0        Non-UE  ladies' CROPP  t-shirts_s_s              A
# 1        Non-UE  ladies' CROPP  t-shirts_s_s              B
# 2        Non-UE  ladies' CROPP  t-shirts_s_s              C
# 3        Non-UE  ladies' CROPP  t-shirts_s_s              D
#
#    Total Stores Count
# 0                  11
# 1                   5
# 2                   7
# 3                   1

# %%
df.loc[0:4, "Country Group":"Total Stores Count"]
# Out:
#   Country Group     Department      Subclass Store Category  \
# 0        Non-UE  ladies' CROPP  t-shirts_s_s              A
# 1        Non-UE  ladies' CROPP  t-shirts_s_s              B
# 2        Non-UE  ladies' CROPP  t-shirts_s_s              C
# 3        Non-UE  ladies' CROPP  t-shirts_s_s              D
# 4        RUSSIA  ladies' CROPP  t-shirts_s_s              A
#
#    Total Stores Count
# 0                  11
# 1                   5
# 2                   7
# 3                   1
# 4                  18
