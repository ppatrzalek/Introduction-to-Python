# %%
import pandas as pd

# %%
excel_path = "Datasets/SubclassDemand_CROPP.xlsx"
Demand = pd.read_excel(excel_path, sep = ";")
Demand.head()
# Out:
#   Country Group     Department      Subclass Store Category  \
# 0        Non-UE  ladies' CROPP  t-shirts_s_s              A
# 1        Non-UE  ladies' CROPP  t-shirts_s_s              B
# 2        Non-UE  ladies' CROPP  t-shirts_s_s              C
# 3        Non-UE  ladies' CROPP  t-shirts_s_s              D
# 4        RUSSIA  ladies' CROPP  t-shirts_s_s              A
#
#    Total Stores Count  Avg Stcl Cnt  Store Count  Demand Avg  \
# 0                  11           137           10   84.336166
# 1                   5           136            4   23.789995
# 2                   7           118            7   31.042260
# 3                   1           143            1    2.919945
# 4                  18           149           18  169.276232
#
#    Demand Avg With Min/Max  Avg Stcl Cnt Max  Store Count.1  Demand Max  \
# 0                84.336166                20             10  232.726233
# 1                23.789995                20              4   59.437176
# ...

# %%
Best_Demand = Demand[Demand['Avg Wsp Alokacyjny'] >= 15]
Best_Demand.head()
# Out:
#     Country Group     Department        Subclass Store Category  \
# 105        Non-UE  ladies' CROPP  jeans_trousers              A
# 281        Non-UE    men's CROPP   outer_jackets              A
# 284        RUSSIA    men's CROPP   outer_jackets              A
# 316        Non-UE    men's CROPP           coats              A
# 319        RUSSIA    men's CROPP           coats              A
#
#      Total Stores Count  Avg Stcl Cnt  Store Count  Demand Avg  \
# 105                   7            59            5  120.979785
# 281                   7            19            6  112.708542
# 284                  35            22           35  638.727455
# 316                   7             2            6  128.784275
# 319                  35             3           35  637.914515
#
#      Demand Avg With Min/Max  Avg Stcl Cnt Max  Store Count.1   Demand Max  \
# 105               120.979785                 8              5   292.958589
# ...

# %%
# Save as csv or xlsx
Best_Demand.to_excel('Datasets/Best_SubclassDemand_CROPP.xlsx')
Best_Demand.to_csv('Datasets/Best_SubclassDemand_CROPP.csv')
