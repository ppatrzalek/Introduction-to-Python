# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.plot(5, 5, 'o')
plt.title("Plot")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
df = {'India' :[8880, 8670, 8147, 7338, 5704], 'China' :[5123, 6682, 3308, 1863, 1527]}
india_china_df = pd.DataFrame(df, index = ['1980', '1981', '1982', '1983', '1984'])
india_china_df
# Out:
#       India  China
# 1980   8880   5123
# 1981   8670   6682
# 1982   8147   3308
# 1983   7338   1863
# 1984   5704   1527

# %%
# Line Plot
india_china_df.plot(kind = 'line')

# %%
# Histogram
india_china_df['China'].plot(kind = 'hist')
